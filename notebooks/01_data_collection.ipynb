# %% [markdown]
# # 01 Data Collection
#
# ## Project question
# Can we predict median private rent across local areas using economic and housing market indicators?
#
# ## Target variable
# Median monthly private rent by local authority.
#
# ## Candidate features
# - Median income
# - Median house price
# - Region
# - Population density
# - Unemployment rate
#
# ## First milestone
# Create one merged dataset at local authority level.
